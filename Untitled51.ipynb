# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaKarthikReddy/DLL/blob/main/Untitled51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1
# Out:
# 1

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

# 1. Load and Prepare Data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalize
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten images (28x28 → 784)
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# 2. Define Encoder & Decoder
input_dim = 784
encoding_dim = 32  # compressed representation

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='sigmoid')(input_layer)

# Decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# 3. Create Autoencoder Model
autoencoder = Model(input_layer, decoded)

# 4. Compile Model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 5. Train Model
autoencoder.fit(
    x_train, x_train,
    epochs=50,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

# 6. Predict (Reconstruct images)
decoded_imgs = autoencoder.predict(x_test)

# 7. Visualization
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis("off")

    # Reconstructed
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis("off")

plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.5188 - val_loss: 0.4929
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4861 - val_loss: 0.4754
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4650 - val_loss: 0.4564
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4479 - val_loss: 0.4415
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4339 - val_loss: 0.4288
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4225 - val_loss: 0.4191
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4138 - val_loss: 0.4107
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4036 - val_loss: 0.4003
# Epoch 9/50
# ...

# %%
from sklearn.metrics import mean_squared_error

# Overall MSE
mse = np.mean(np.power(x_test - decoded_imgs, 2))
print("Overall MSE:", mse)

# MSE per image (optional)
mse_per_image = [mean_squared_error(x_test[i], decoded_imgs[i]) for i in range(len(x_test))]
print("Sample MSE (first 5 images):", mse_per_image[:5])
# Out:
# Overall MSE: 0.01753485
# Sample MSE (first 5 images): [0.010356402024626732, 0.028524266555905342, 0.010849670507013798, 0.010767166502773762, 0.016464898362755775]

# %%
from skimage.metrics import structural_similarity as ssim

ssim_scores = []

for i in range(len(x_test)):
    original = x_test[i].reshape(28, 28)
    reconstructed = decoded_imgs[i].reshape(28, 28)

    score = ssim(original, reconstructed, data_range=1.0)
    ssim_scores.append(score)

# Average SSIM
print("Average SSIM:", np.mean(ssim_scores))

# Sample SSIM values
print("Sample SSIM (first 5 images):", ssim_scores[:5])
# Out:
# Average SSIM: 0.6201470049797699
# Sample SSIM (first 5 images): [np.float64(0.6852836528512041), np.float64(0.6895784728752434), np.float64(0.8652650204464054), np.float64(0.7987933153640633), np.float64(0.5040373526160482)]

# %%
history = autoencoder.fit(
    x_train, x_train,
    epochs=50,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2964 - val_loss: 0.2985
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2962 - val_loss: 0.2984
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2960 - val_loss: 0.2981
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2958 - val_loss: 0.2981
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2957 - val_loss: 0.2979
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2955 - val_loss: 0.2977
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2954 - val_loss: 0.2978
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2952 - val_loss: 0.2974
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2951 - val_loss: 0.2974
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2950 - val_loss: 0.2973
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2949 - val_loss: 0.2972
# ...

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.show()

# %%
n = 10
plt.figure(figsize=(20, 5))

for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis("off")

    # Reconstructed with metrics
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')

    mse_val = mean_squared_error(x_test[i], decoded_imgs[i])
    ssim_val = ssim(
        x_test[i].reshape(28,28),
        decoded_imgs[i].reshape(28,28),
        data_range=1.0
    )

    plt.title(f"MSE:{mse_val:.4f}\nSSIM:{ssim_val:.4f}")
    plt.axis("off")

plt.show()

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from skimage.metrics import structural_similarity as ssim

# 1. Load and Prepare Data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), -1))
x_test = x_test.reshape((len(x_test), -1))

# 2. Define Autoencoder
input_dim = 784
encoding_dim = 90

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='sigmoid')(input_layer)
decoded = Dense(input_dim, activation='sigmoid')(encoded)

autoencoder = Model(input_layer, decoded)

# 3. Compile
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 4. Train
history = autoencoder.fit(
    x_train, x_train,
    epochs=50,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

# 5. Predict
decoded_imgs = autoencoder.predict(x_test)

# =========================
# 6. Evaluation Metrics
# =========================

# MSE
mse = np.mean(np.power(x_test - decoded_imgs, 2))

# SSIM
ssim_scores = []
for i in range(len(x_test)):
    original = x_test[i].reshape(28, 28)
    reconstructed = decoded_imgs[i].reshape(28, 28)
    score = ssim(original, reconstructed, data_range=1.0)
    ssim_scores.append(score)

avg_ssim = np.mean(ssim_scores)

print("\n===== Evaluation Metrics =====")
print("Average MSE:", mse)
print("Average SSIM:", avg_ssim)

# =========================
# 7. Final Verdict
# =========================

if mse < 0.02 and avg_ssim > 0.80:
    verdict = "GOOD RECONSTRUCTION"
elif mse < 0.05 and avg_ssim > 0.60:
    verdict = "MODERATE RECONSTRUCTION"
else:
    verdict = "POOR RECONSTRUCTION"

print("\n===== FINAL VERDICT =====")
print(verdict)

# =========================
# 8. Loss Curve
# =========================

plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.show()

# =========================
# 9. Visualization with Metrics
# =========================

n = 10
plt.figure(figsize=(20, 5))

for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title("Original")
    plt.axis("off")

    # Reconstructed
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')

    mse_val = mean_squared_error(x_test[i], decoded_imgs[i])
    ssim_val = ssim(
        x_test[i].reshape(28, 28),
        decoded_imgs[i].reshape(28, 28),
        data_range=1.0
    )

    plt.title(f"MSE:{mse_val:.4f}\nSSIM:{ssim_val:.4f}")
    plt.axis("off")

plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.4457 - val_loss: 0.3879
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3627 - val_loss: 0.3462
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3340 - val_loss: 0.3279
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3198 - val_loss: 0.3166
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3106 - val_loss: 0.3091
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3041 - val_loss: 0.3036
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2992 - val_loss: 0.2992
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2953 - val_loss: 0.2959
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2922 - val_loss: 0.2930
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2897 - val_loss: 0.2908
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2876 - val_loss: 0.2889
# ...
