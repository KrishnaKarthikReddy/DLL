# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaKarthikReddy/DLL/blob/main/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1
# Out:
# 1

# %% [markdown]
# ## **MNIST DATASET**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
import numpy as np

# Load data
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.

# Flatten automatically in model
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# # **No Regularization**

# %%
def build_baseline():
    model = keras.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(256, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

baseline = build_baseline()
baseline.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8852 - loss: 0.3831 - val_accuracy: 0.9723 - val_loss: 0.0920
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9709 - loss: 0.0932 - val_accuracy: 0.9808 - val_loss: 0.0718
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9800 - loss: 0.0613 - val_accuracy: 0.9773 - val_loss: 0.0748
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9877 - loss: 0.0383 - val_accuracy: 0.9787 - val_loss: 0.0845
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9884 - loss: 0.0353 - val_accuracy: 0.9777 - val_loss: 0.0840
# Epoch 6/10
# ...

# %% [markdown]
# # **1. L2 Regularization**

# %%
def build_l2():
    model = keras.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(256, activation="relu",
                     kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dense(128, activation="relu",
                     kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

l2_model = build_l2()
l2_model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8868 - loss: 0.4259 - val_accuracy: 0.9745 - val_loss: 0.1414
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9695 - loss: 0.1506 - val_accuracy: 0.9750 - val_loss: 0.1431
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9783 - loss: 0.1255 - val_accuracy: 0.9770 - val_loss: 0.1354
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9826 - loss: 0.1113 - val_accuracy: 0.9773 - val_loss: 0.1332
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9857 - loss: 0.1003 - val_accuracy: 0.9743 - val_loss: 0.1387
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9865 - loss: 0.0957 - val_accuracy: 0.9802 - val_loss: 0.1246
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9878 - loss: 0.0910 - val_accuracy: 0.9728 - val_loss: 0.1364
# Epoch 8/10
# ...

# %% [markdown]
# # **2. Data Augmentation**

# %%
data_augmentation = keras.Sequential([
    layers.RandomRotation(0.1),
    layers.RandomTranslation(0.1, 0.1)
])

def build_aug():
    model = keras.Sequential([
        layers.Input(shape=(28, 28)),
        data_augmentation,
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

aug_model = build_aug()
aug_model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.1499 - loss: 2.2784 - val_accuracy: 0.6308 - val_loss: 1.6242
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1814 - loss: 2.2365 - val_accuracy: 0.7405 - val_loss: 1.3864
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1845 - loss: 2.2368 - val_accuracy: 0.7577 - val_loss: 1.3421
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1892 - loss: 2.2322 - val_accuracy: 0.7475 - val_loss: 1.4388
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1915 - loss: 2.2227 - val_accuracy: 0.7402 - val_loss: 1.3823
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1890 - loss: 2.2251 - val_accuracy: 0.7825 - val_loss: 1.4690
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.1925 - loss: 2.2216 - val_accuracy: 0.7187 - val_loss: 1.3770
# Epoch 8/10
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Load data
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.

# Proper MNIST augmentation
data_augmentation = keras.Sequential([
    layers.RandomRotation(0.05),      # ±5% rotation (very mild)
    layers.RandomZoom(0.05),          # small zoom
    layers.RandomTranslation(0.05, 0.05)  # small shift
])

def build_aug_model():
    model = keras.Sequential([
        layers.Input(shape=(28, 28)),
        data_augmentation,
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

aug_model = build_aug_model()
history = aug_model.fit(
    x_train, y_train,
    epochs=10,
    validation_split=0.1
)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.2557 - loss: 2.0978 - val_accuracy: 0.8610 - val_loss: 0.8403
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3074 - loss: 1.9805 - val_accuracy: 0.8880 - val_loss: 0.6358
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3226 - loss: 1.9365 - val_accuracy: 0.9032 - val_loss: 0.6774
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3168 - loss: 1.9553 - val_accuracy: 0.9148 - val_loss: 0.5833
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3246 - loss: 1.9280 - val_accuracy: 0.9005 - val_loss: 0.5814
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3198 - loss: 1.9358 - val_accuracy: 0.8952 - val_loss: 0.6095
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3352 - loss: 1.8918 - val_accuracy: 0.9103 - val_loss: 0.6261
# Epoch 8/10
# ...

# %%
# Define augmentation (keep it mild!)
data_augmentation = keras.Sequential([
    layers.RandomRotation(0.03)
])

def build_aug_model():
    model = keras.Sequential([
        layers.Input(shape=(28, 28)),
        data_augmentation,
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# Build model
aug_model = build_aug_model()

# Train model
history = aug_model.fit(
    x_train, y_train,
    epochs=10,
    validation_split=0.1
)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6567 - loss: 1.0273 - val_accuracy: 0.9368 - val_loss: 0.2098
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8001 - loss: 0.5775 - val_accuracy: 0.9545 - val_loss: 0.1486
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8313 - loss: 0.4919 - val_accuracy: 0.9577 - val_loss: 0.1427
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8462 - loss: 0.4508 - val_accuracy: 0.9603 - val_loss: 0.1239
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8492 - loss: 0.4352 - val_accuracy: 0.9550 - val_loss: 0.1428
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8543 - loss: 0.4154 - val_accuracy: 0.9713 - val_loss: 0.1000
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8576 - loss: 0.4178 - val_accuracy: 0.9670 - val_loss: 0.1123
# Epoch 8/10
# ...

# %% [markdown]
# # **3. Parameter Sharing**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Shared layer (256 → 256)
shared_layer = layers.Dense(256, activation="relu")

def build_tied():
    inputs = keras.Input(shape=(28, 28))

    x = layers.Flatten()(inputs)        # 784
    x = layers.Dense(256, activation="relu")(x)  # 784 → 256

    x = shared_layer(x)   # 256 → 256
    x = shared_layer(x)   # 256 → 256  (tied weights)

    outputs = layers.Dense(10, activation="softmax")(x)

    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

tied_model = build_tied()
tied_model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8832 - loss: 0.3832 - val_accuracy: 0.9688 - val_loss: 0.1002
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9679 - loss: 0.1020 - val_accuracy: 0.9718 - val_loss: 0.0851
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9799 - loss: 0.0644 - val_accuracy: 0.9715 - val_loss: 0.0972
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9837 - loss: 0.0530 - val_accuracy: 0.9753 - val_loss: 0.0859
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9876 - loss: 0.0388 - val_accuracy: 0.9802 - val_loss: 0.0713
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9898 - loss: 0.0322 - val_accuracy: 0.9797 - val_loss: 0.0836
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9908 - loss: 0.0270 - val_accuracy: 0.9793 - val_loss: 0.0832
# Epoch 8/10
# ...

# %% [markdown]
# # **4.Adding Noise to Inputs**

# %%
def build_noise():
    model = keras.Sequential([
        layers.GaussianNoise(0.1, input_shape=(28,28)),
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

noise_model = build_noise()
noise_model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/regularization/gaussian_noise.py:29: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8800 - loss: 0.3959 - val_accuracy: 0.9662 - val_loss: 0.1037
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9680 - loss: 0.1035 - val_accuracy: 0.9742 - val_loss: 0.0969
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9771 - loss: 0.0718 - val_accuracy: 0.9790 - val_loss: 0.0762
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9829 - loss: 0.0535 - val_accuracy: 0.9777 - val_loss: 0.0778
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9871 - loss: 0.0414 - val_accuracy: 0.9790 - val_loss: 0.0776
# Epoch 6/10
# ...

# %% [markdown]
# # **5. Early Stopping**

# %%
early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

early_model = build_baseline()
early_model.fit(x_train, y_train,
                epochs=10,
                validation_split=0.1,
                callbacks=[early_stop])
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8845 - loss: 0.3894 - val_accuracy: 0.9713 - val_loss: 0.0968
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9704 - loss: 0.0930 - val_accuracy: 0.9705 - val_loss: 0.1007
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9812 - loss: 0.0594 - val_accuracy: 0.9773 - val_loss: 0.0851
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9856 - loss: 0.0444 - val_accuracy: 0.9773 - val_loss: 0.0791
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9892 - loss: 0.0332 - val_accuracy: 0.9765 - val_loss: 0.1014
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9922 - loss: 0.0249 - val_accuracy: 0.9795 - val_loss: 0.0826
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9917 - loss: 0.0249 - val_accuracy: 0.9782 - val_loss: 0.0993

# %% [markdown]
# # **6. Drop Out**

# %%
def build_dropout():
    model = keras.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(256, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

drop_model = build_dropout()
drop_model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7656 - loss: 0.7209 - val_accuracy: 0.9660 - val_loss: 0.1163
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9294 - loss: 0.2401 - val_accuracy: 0.9705 - val_loss: 0.0980
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9448 - loss: 0.1985 - val_accuracy: 0.9775 - val_loss: 0.0803
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9494 - loss: 0.1737 - val_accuracy: 0.9775 - val_loss: 0.0775
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9573 - loss: 0.1498 - val_accuracy: 0.9787 - val_loss: 0.0709
# Epoch 6/10
# ...

# %% [markdown]
# # **7. Ensemble Methods**
#
# **Train multiple models and average predictions.**

# %%
models = [build_baseline() for _ in range(3)]

for m in models:
    m.fit(x_train, y_train, epochs=10, verbose=0)

def ensemble_predict(x):
    preds = np.mean([m.predict(x) for m in models], axis=0)
    return np.argmax(preds, axis=1)

ensemble_accuracy = np.mean(
    ensemble_predict(x_test) == y_test
)

print("Ensemble Accuracy:", ensemble_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Ensemble Accuracy: 0.9851

# %%
1
# Out:
# 1

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 1. Load and preprocess the data
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape data to include the channel dimension (28, 28, 1)
x_train = x_train.reshape((-1, 28, 28, 1))
x_test = x_test.reshape((-1, 28, 28, 1))

# 2. Build the CNN Model
model = models.Sequential([
    # First Convolutional Layer
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),

    # Second Convolutional Layer
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Flatten and Dense Layers
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax') # 10 output classes
])

# 3. Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 4. Train the model
model.fit(x_train, y_train, epochs=5, batch_size=64)

# 5. Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'\nTest accuracy: {test_acc:.4f}')
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8816 - loss: 0.4114
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9830 - loss: 0.0549
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9883 - loss: 0.0381
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9915 - loss: 0.0271
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9939 - loss: 0.0204
# 313/313 - 2s - 6ms/step - accuracy: 0.9877 - loss: 0.0348
#
# Test accuracy: 0.9877

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load and normalize data
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

def create_optimized_cnn():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),

        # Block 1
        layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),

        # Block 2
        layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.4),
        layers.Dense(10, activation='softmax')
    ])
    return model
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-3 * 0.9**epoch
)

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.1),
  layers.RandomZoom(0.1),
])

# Apply as the first layer of your model

# %%
import matplotlib.pyplot as plt

# Create the model
model = create_optimized_cnn() # Using the CIFAR-10 model from before

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model and save the progress to 'history'
print("Starting training... If no output appears below, check your data shapes.")
history = model.fit(train_images, train_labels,
                    epochs=10,
                    batch_size=64,
                    validation_split=0.2,
                    verbose=1) # Verbose=1 ensures the progress bar shows
# Out:
# Starting training... If no output appears below, check your data shapes.
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.2510 - loss: 2.0565 - val_accuracy: 0.4197 - val_loss: 1.6445
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4386 - loss: 1.5120 - val_accuracy: 0.5660 - val_loss: 1.2543
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5207 - loss: 1.3231 - val_accuracy: 0.5891 - val_loss: 1.1522
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5822 - loss: 1.1666 - val_accuracy: 0.6627 - val_loss: 0.9577
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6383 - loss: 1.0395 - val_accuracy: 0.6732 - val_loss: 0.9414
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6670 - loss: 0.9583 - val_accuracy: 0.7018 - val_loss: 0.8734
# Epoch 7/10
# ...

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy Evolution')
    plt.legend()

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss Evolution')
    plt.legend()

    plt.show()

plot_history(history)
