# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaKarthikReddy/DLL/blob/main/Untitled49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1
# Out:
# 1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Common Hyperparameters
batch_size = 64
learning_rate = 0.001
epochs = 10

# Load MNIST
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
train_dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 56.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.70MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 14.0MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.96MB/s]

# %%
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 256),
    nn.ReLU(),
    nn.Linear(256, 10)
)

# weight_decay is the lambda parameter for L2
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

# %%
# Updated transforms for augmentation
aug_transform = transforms.Compose([
    transforms.RandomRotation(10), # Rotate +/- 10 degrees
    transforms.RandomAffine(0, translate=(0.1, 0.1)), # Shift slightly
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

aug_train_dataset = datasets.MNIST('./data', train=True, transform=aug_transform)
aug_loader = DataLoader(aug_train_dataset, batch_size=batch_size, shuffle=True)

# %%
class TiedLinear(nn.Module):
    def __init__(self, target_layer):
        super().__init__()
        self.target_layer = target_layer # Shares the weight of another layer

    def forward(self, x):
        # Use the transpose of the target layer's weights
        return torch.matmul(x, self.target_layer.weight)

# Example: A Symmetric Autoencoder-style MLP
layer1 = nn.Linear(784, 256)
tied_layer = TiedLinear(layer1) # This layer uses layer1's weights

# %%
def add_input_noise(ins):
    return ins + torch.randn_like(ins) * 0.1

# For Output Noise (Label Smoothing)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# Inside training loop:
# outputs = model(add_input_noise(inputs))
# loss = criterion(outputs, targets)

# %%
best_val_loss = float('inf')
patience = 3
counter = 0

for epoch in range(epochs):
    # ... Training Code ...
    val_loss = validate(model) # Hypothetical validation function

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), 'best_model.pth')
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered!")
            break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_488/3405196113.py in <cell line: 0>()
#       5 for epoch in range(epochs):
#       6     # ... Training Code ...
# ----> 7     val_loss = validate(model) # Hypothetical validation function
#       8
#       9     if val_loss < best_val_loss:
#
# NameError: name 'validate' is not defined

# %%
models = [SimpleMLP() for _ in range(5)] # Create 5 identical MLPs
optimizers = [optim.Adam(m.parameters()) for m in models]

# After training all models, aggregate predictions:
def ensemble_predict(models, x):
    outputs = [torch.softmax(m(x), dim=1) for m in models]
    avg_output = torch.stack(outputs).mean(0)
    return avg_output.argmax(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_488/2229864473.py in <cell line: 0>()
# ----> 1 models = [SimpleMLP() for _ in range(5)] # Create 5 identical MLPs
#       2 optimizers = [optim.Adam(m.parameters()) for m in models]
#       3
#       4 # After training all models, aggregate predictions:
#       5 def ensemble_predict(models, x):
#
# NameError: name 'SimpleMLP' is not defined

# %%
model_with_dropout = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 256),
    nn.ReLU(),
    nn.Dropout(0.5), # 50% chance of dropping a neuron
    nn.Linear(256, 10)
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torchvision import datasets
from torch.utils.data import DataLoader

# Hyperparameters [cite: 11-15]
batch_size = 64
learning_rate = 0.001
epochs = 10

# Load MNIST without transforms
train_dataset = datasets.MNIST('./data', train=True, download=True)

def manual_preprocess(batch_images):
    # Manual conversion: PIL/Numpy -> Tensor, Scaling 0-1, and Flattening
    tensors = [torch.from_numpy(np.array(img)).float() / 255.0 for img in batch_images]
    return torch.stack(tensors).view(-1, 784)

# Base Model Architecture (SimpleMLP) [cite: 38-44]
class SimpleMLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )
    def forward(self, x): return self.main(x)

# %%
model = SimpleMLP()
# weight_decay is the lambda parameter for L2
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4) [cite: 47]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_488/3020528411.py in <cell line: 0>()
#       1 model = SimpleMLP()
#       2 # weight_decay is the lambda parameter for L2
# ----> 3 optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4) [cite: 47]
#
# NameError: name 'cite' is not defined

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# 1. Data Augmentation & Noise
# We add Gaussian noise and a slight rotation to force the model to generalize.
class AddGaussianNoise(object):
    def __init__(self, mean=0., std=0.1):
        self.std = std
        self.mean = mean
    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomRotation(10), # Augmentation
    AddGaussianNoise(0., 0.1)     # Adding noise
])

train_dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
val_dataset = datasets.MNIST('./data', train=False, transform=transforms.ToTensor())

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# 2. Architecture with Dropout
class RegularizedMLP(nn.Module):
    def __init__(self):
        super(RegularizedMLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Dropout(0.3), # Dropout layer
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.3), # Dropout layer
            nn.Linear(256, 10)
        )
    def forward(self, x):
        return self.layers(x)

model = RegularizedMLP()

# 3. L2 Regularization (weight_decay)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()

# 4. Early Stopping Mechanism
class EarlyStopping:
    def __init__(self, patience=3):
        self.patience = patience
        self.counter = 0
        self.best_loss = float('inf')

    def __call__(self, val_loss):
        if val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0
            return False # Keep training
        else:
            self.counter += 1
            return self.counter >= self.patience # Stop training

early_stopper = EarlyStopping(patience=3)

# Training Loop
for epoch in range(20):
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

    # Validation Phase
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data, target in val_loader:
            val_loss += criterion(model(data), target).item()

    val_loss /= len(val_loader)
    print(f"Epoch {epoch+1}, Val Loss: {val_loss:.4f}")

    if early_stopper(val_loss):
        print("Early stopping triggered!")
        break
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.6MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 459kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.40MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.84MB/s]
# Epoch 1, Val Loss: 0.1099
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_489/2126625673.py in <cell line: 0>()
#      70 for epoch in range(20):
#      71     model.train()
# ---> 72     for data, target in train_loader:
#      73         optimizer.zero_grad()
#      74         output = model(data)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
# ...
